# %% [markdown]
# <a href="https://colab.research.google.com/github/MohmedAAK/-Advanced-computer-vision-v1/blob/main/Advanced%20computer%20vision/team3/descriptors_and_matching.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np 
img = cv2.imread('/content/FB_IMG_1541366075734.jpg')
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=442x600 at 0x7F6A49D6F790>

# %%
# !cd <opencv_build_directory>
! cmake -DOPENCV_EXTRA_MODULES_PATH=<opencv_contrib>/modules <opencv_source_directory>
! make -j5
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `newline'
# /bin/bash: -c: line 0: `cd <opencv_build_directory>'
# /bin/bash: -c: line 0: syntax error near unexpected token `newline'
# /bin/bash: -c: line 0: ` cmake -DOPENCV_EXTRA_MODULES_PATH=<opencv_contrib>/modules <opencv_source_directory>'
# make: *** No targets specified and no makefile found.  Stop.

# %%
# !cmake -DOPENCV_EXTRA_MODULES_PATH=<opencv_contrib>/modules -DBUILD_opencv_legacy=OFF <opencv_source_directory>
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `newline'
# /bin/bash: -c: line 0: `cmake -DOPENCV_EXTRA_MODULES_PATH=<opencv_contrib>/modules -DBUILD_opencv_legacy=OFF <opencv_source_directory>'

# %%
# !pip install opencv-contrib-python==4.4.0.44

# %%
gray= cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
sift = cv2.xfeatures2d.SIFT_create()
keypoints_1, descriptors_1 = sift.detectAndCompute(img,None)

img_1 = cv2.drawKeypoints(gray,keypoints_1,img)

# %%
cv2_imshow(img_1)
# Out:
# <PIL.Image.Image image mode=RGB size=442x600 at 0x7F6A39C24990>

# %%
img1 = cv2.imread('/content/FB_IMG_1541366075734.jpg')  
img2 = cv2.imread('/content/mm.jpeg') 

img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
cv2_imshow(img1)
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=L size=442x600 at 0x7F6A39BC5750>
# <PIL.Image.Image image mode=L size=508x510 at 0x7F6A39BC5910>

# %%
#sift
sift = cv2.xfeatures2d.SIFT_create()

keypoints_1, descriptors_1 = sift.detectAndCompute(img1,None)
keypoints_2, descriptors_2 = sift.detectAndCompute(img2,None)

len(keypoints_1), len(keypoints_2)
# Out:
# (1053, 936)

# %%
#feature matching
bf = cv2.BFMatcher(cv2.NORM_L1, crossCheck=True)

matches = bf.match(descriptors_1,descriptors_2)
matches = sorted(matches, key = lambda x:x.distance)

img3 = cv2.drawMatches(img1, keypoints_1, img2, keypoints_2, matches[:50], img2, flags=2)

# %%
cv2_imshow(img3)
# Out:
# <PIL.Image.Image image mode=RGB size=950x600 at 0x7F6A39B4AD90>
